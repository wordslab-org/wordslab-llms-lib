# %% [raw]
# ---
# description: Database of Huggingface LLM models
# output-file: models.html
# title: models
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| echo: false
#| output: asis
show_doc(test)
# Out:
# ---
#
# [source](https://github.com/wordslab-org/wordslab-llms-lib/blob/main/wordslab_llms/models.py#L7){target="_blank" style="float:right; font-size:smaller"}
#
# ### test
#
# >      test ()
